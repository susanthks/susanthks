# %%
# %%writefile medint.json
# {"intents":[
#             {
#              "tag":"greetings",
#              "patterns": ["hello","hey","hi","good day","greetings","what's up?","how is it going"],
#              "responses":["hello","hey!","what can i do for you?"]
#             },
#             {
#              "tag":"goodbye",
#              "patterns": ["cya","see you later","goodbye","have a good day","bye","cao","see ya"],
#              "responses":["have a nice day","goodbye"]
#             },
#             {
#              "tag":"age",
#              "patterns": ["how old","how old are you?","what is your age","how old are you","age?"],
#              "responses":["I get reborn after every compilation","hey!","my owners are averagely 20 years!"]
#             },
#             {
#              "tag":"name",
#              "patterns": ["what is your name","what should i call you","what's your name?","who are you?","can you tell me your name"],
#              "responses":["you can call me Medbot!","i am Medbot!","i am Medbot your medical assistant"]
#             },
#             {
#              "tag":"common cold symptoms",
#              "patterns": ["Runny or stuffy nose","Sore throat","Cough","Congestion","Slight body aches or a mild headache","Sneezing","Low-grade fever","Generally feeling unwell (malaise)"],
#              "responses":["It seems that you are suffering from common cold"]
#             },
#             {
#              "tag":"fever symptoms",
#              "patterns":["Sweating","Chills and shivering","Headache","Muscle aches","Loss of appetite","Irritability","Dehydration","General weakness"],
#              "responses":["It seems that you are suffering from fever"]
#             },
#             {
#              "tag":"Diabetes symptoms",
#              "patterns":["increased hunger","increased thirst","weight loss","frequent urination","blurry vision","extreme fatigue"],
#              "responses":["It seems that you are suffering from Diabetes"]
#             },
#             {
#              "tag":"Typhoid",
#              "patterns":["Continues fever, headache , slow pulse rate","reddish rashes appear on the belly","ulcers rupture"],
#              "responses":["It seems that you are suffering from Typhoid"]
#             },
#             {
#              "tag":"Depression symptoms",
#              "patterns":["Hopeless outlook","Lost interest","Increased fatigue","sleep problem","Anxiety","change in weight","Looking at death"],
#              "responses":["It seem that you are suffering from depression"]
#             },
#             {
#              "tag": "Bronchitis",
#              "patterns":["Cough is severe or lasts longer than three weeks", "Constant fever (temperature 38 degree celsius or above) for more than three days","Cough up mucus streaked with blood","having underlying heart or lung condition such as asthma or heart failure"],
#              "responses":["It seems that you are suffering from depression"]
#             },
#             {
#              "tag":"Allergy",
#              "patterns":["Irritation","runny nose","stuffy nose","puffy","watery eyes","sneezing","Inflammed,itchy nose and throught","Skin rashes","Diarrhea","nausea","vomiting excessing gas in digestion","swelling of lips,face,tongue","itchiness","difficulty in breathing"],
#              "responses":["it seems that you are suffering from Allergy"]
#             },
#             {
#              "tag":"Chest infection",
#              "patterns":["Persistant cough","Cough of yellow or green phlegm(thick mucus) or coughing up blood","breathlessness or rapid and shallow breathing","wheezing","high temperature fever","rapid heartbeat","chest pain or tightness","feeling confused and disorientated"],
#              "responses":["it seems that you are suffering from chest infection"]
#             },
#             {
#              "tag":"Asthma symptoms",
#              "patterns":["coughing","tightness in the chest","shortness of breath","difficulty talking","panic","fatigue"],
#              "responses":["It seem that you are suffering from Asthma"]
#             },
#             {
#              "tag":"Chicken pox",
#              "patterns":["Fever , headache and lose of apetite","Dark red - coloured rash on the back and chest which spreads on the whole body later change into vessicles","crusts are formed"],
#              "responses":["It seem that you are suffering from Chicken pox"]
#             },
#             {
#              "tag":"eczema",
#              "patterns":["Dry cracked skin ","itchiness (pruritus)","rash on swollen skin that varies in color depending on your skin color","small , raced bumps on brown or black skin ", "oozing and crusting","thickened skin","darkening of skin around the eyes","Raw sensitive skin from scratching"],
#              "responses":["It seem that you are suffering from eczema"]
#             },
#             {
#              "tag":"common cold prevention",
#              "patterns":["What medicines can I buy to help me with my common cold?","tell me some prevention method from common cold","What should I eat or drink if i am suffering from common cold?","How can I keep from getting a cold or the flu?"],
#              "responses":["medicines you can consume : Dextromethorphan,Decongestant,Diphenhydramine,Crocin Cold & Flu Max, preventions that you must follow :Wash your hands,Avoid touching your face,Clean frequently used surfaces,Use hand sanitizers,SUGGESTED FOODS ARE:Garlic,Vitamin C–containing fruits,Leafy greens,Broccoli,Oatmeal,Spices,Chicken Soup"]
#             },
#             {
#              "tag":"fever prevention",
#              "patterns":["What medicines can I buy to help me with my fever?","tell me some prevention method from fever","What should I eat or drink if i am suffering from fever?","How can I keep from getting a fever?"],
#              "responses":["medicines you can consume : acetaminophen ,ibuprofen,aspirin,Crocin Cold & Flu Max, prevention that you must follow :Wash your hands,Cover your mouth when you cough and your nose when you sneeze,Clean frequently used surfaces,Avoid sharing cups, glasses, and eating utensils with other people.,SUGGESTED FOODS ARE:Garlic,Vitamin C–containing fruits,Leafy greens,Broccoli,Oatmeal,Spices,Chicken Soup"]
#             },
#             {
#              "tag":"Typhoid  prevention",
#              "patterns":["tell me some prevention method from typhoid","How can I cure from typhoid","How can I keep from getting a typhoid"],
#              "responses":["Anti-typhoid inoculation should be given","avoid taking exposed food and drinks","proper sanitation and cleanlinessness should be maintained","Proper disposal of excreta of the patient","anti-biotics should be administrated"]
#             },
#             {
#              "tag":"diabetes prevention",
#              "patterns":["What medicines can I buy to help me with my diabetes?","tell me some prevention method from diabetes","What should I eat or drink if i am suffering from diabetes?","How can I keep from getting diabetes?"],
#              "responses":["medicines you can consume : Insulin ,Amylinomimetic drug,Dipeptidyl peptidase-4 (DPP-4) inhibitor, prevention that you must follow :Cut Sugar and Refined Carbs From Your Diet,Work Out Regularly,Drink Water as Your Primary Beverage,Lose Weight If You’re Overweight or Obese,Quit Smoking, Follow a Very-Low-Carb Diet,Watch Portion Sizes,SUGGESTED FOODS ARE:Leafy greens,Avocados,Eggs"]
#             },
#             {
#              "tag":"depression prevention",
#              "patterns":["What medicines can I buy to help me with my depression?","tell me some prevention method from depression","What should I eat or drink if i am suffering from depression?","How can I keep from getting depression?"],
#              "responses":["medicines you can consume :  brexpiprazole, quetiapine,olanzapine, prevention that you must follow :Exercise regularly,Cut back on social media time,Drink Water as Your Primary Beverage,Build strong relationships,Minimize your daily choices, Follow a Very-Low-Carb Diet,SUGGESTED FOODS ARE:Get Enough Vitamin D,Include Omega-3 Fatty Acids,Beans and legumes"]
#             },
#             {
#              "tag":"asthma prevention",
#              "patterns":["What medicines can I buy to help me with my asthma?","tell me some prevention method from asthma","What should I eat or drink if i am suffering from asthma?","How can I keep from getting asthma?"],
#              "responses":["medicines you can consume : epinephrine,anticholinergic,Proair HFA, prevention that you must follow : Identify Asthma Triggers, Stay Away From Allergens,Avoid Smoke of Any Type,SUGGESTED FOODS ARE:carrots,juice,eggs,broccoli,cantaloupe,milk"]
#             },
#             {
#              "tag":"Chest infection prevention",
#              "patterns":["Tell me some prevention method from chest infection","What are the things which keep on my mind when I have chest infection","How can I recover my chest infection"],
#              "responses":["get plenty of rest,drink lot of fluid to prevent dehydration and to loosen mucus in your lungus, making it easier to cough up","treat headaches, fever and aches, and pains with pain releaves","drink a warm drink of honey and lemon to releave soar throat caused by persistent coughing","raise your head up with extra pillows while you are sleeping to make breathing easier","stop smoking if you smoke"]
#             },
#             {
#              "tag":"Chicken pox prevention",
#              "patterns":["Tell me some prevention for chicken pox","What are the things which keep on my mind when I have chicken pox","How can cure  chicken pox"],
#              "responses":["You should be kept in isolation","clothings, utensils, e.t.c used by the patient should be sterilized","falling crusts should be collected and burnt"]
#             },
#             {
#              "tag":"Consultation",
#              "patterns": ["who should i contact for consultation?","is there any doctor available?","can you give me some suggestions for doctor consultations?","can you set up a meeting with a doctor for consultation?","is there any doctor available for consultation"],
#              "responses":["You can contact various doctors here for any kind of consultation: 1. https://www.1mg.com/online-doctor-consultation, 2. https://www.tatahealth.com/online-doctor-consultation/general-physician, 3. https://www.doconline.com/, or you can pay a visit to your local area doctor or family doctor."]
#             }
#            ]
# }
# Out:
# Overwriting medint.json

# %%
import random
import json
import pickle
import numpy as np
import nltk
# nltk.download('punkt')
# nltk.download('wordnet')
# nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
lemmatizer=WordNetLemmatizer()
intents=json.loads(open('medint.json').read())

words=[]
classes=[]
documents=[]
ignore_letters = ['?','!','.',',']
for intent in intents['intents']:
  for pattern in intent['patterns']:
    word_list = nltk.word_tokenize(pattern)
    words.extend(word_list)
    documents.append((word_list,intent['tag']))
    if intent['tag'] not in classes:
      classes.append(intent['tag'])

# print(documents)
words = [lemmatizer.lemmatize(word) for word in words if words not in ignore_letters]
words = sorted(set(words))
classes = sorted(set(classes))
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
training=[]
output_empty = [0]*len(classes)
for document in documents:
  bag=[]
  word_patterns=document[0]
  word_patterns=[lemmatizer.lemmatize(word.lower()) for word in word_patterns]
  for word in words:
    bag.append(1) if word in word_patterns else bag.append(0)
  output_row = list(output_empty)
  output_row[classes.index(document[1])] = 1
  training.append([bag,output_row])
random.shuffle(training)
training = np.array(training)
train_x = list(training[:, 0])
train_y = list(training[:, 1])
model = Sequential()
model.add(Dense(128,input_shape=(len(train_x[0]),),activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]),activation='softmax'))
sgd=tf.keras.optimizers.legacy.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbotmodel.h5')
print('Done')
# print(words)
# Out:
# 2023-01-18 15:41:36.354081: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-18 15:41:36.556258: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-01-18 15:41:36.556285: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-01-18 15:41:37.382768: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-01-18 15:41:37.382873: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-01-18 15:41:37.382886: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# /tmp/ipykernel_9563/2749354376.py:47: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)
# 2023-01-18 15:41:40.541237: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-01-18 15:41:40.541294: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-01-18 15:41:40.541326: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (sushanth-Inspiron-3584): /proc/driver/nvidia/version does not exist
# 2023-01-18 15:41:40.541693: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/sushanth/anaconda3/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1
200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2120 - accuracy: 0.9398
# Epoch 138/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1926 - accuracy: 0.9323
# Epoch 139/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2224 - accuracy: 0.8947
# Epoch 140/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2839 - accuracy: 0.8722
# Epoch 141/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2671 - accuracy: 0.8947
# Epoch 142/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2843 - accuracy: 0.9023
# Epoch 143/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2488 - accuracy: 0.9173
# Epoch 144/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2739 - accuracy: 0.9173
# Epoch 145/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2503 - accuracy: 0.9248
# Epoch 146/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2237 - accuracy: 0.9248
# Epoch 147/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2453 - accuracy: 0.9248
# Epoch 148/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2565 - accuracy: 0.9248
# Epoch 149/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2166 - accuracy: 0.9248
# Epoch 150/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2208 - accuracy: 0.9173
# Epoch 151/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2784 - accuracy: 0.9098
# Epoch 152/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1990 - accuracy: 0.9248
# Epoch 153/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2103 - accuracy: 0.9323
# Epoch 154/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1569 - accuracy: 0.9549
# Epoch 155/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2314 - accuracy: 0.9098
# Epoch 156/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2274 - accuracy: 0.9323
# Epoch 157/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2131 - accuracy: 0.9098
# Epoch 158/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1797 - accuracy: 0.9173
# Epoch 159/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2802 - accuracy: 0.8797
# Epoch 160/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1378 - accuracy: 0.9549
# Epoch 161/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2126 - accuracy: 0.9323
# Epoch 162/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1698 - accuracy: 0.9549
# Epoch 163/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2123 - accuracy: 0.9098
# Epoch 164/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1744 - accuracy: 0.9474
# Epoch 165/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2393 - accuracy: 0.9023
# Epoch 166/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1989 - accuracy: 0.9173
# Epoch 167/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1840 - accuracy: 0.9248
# Epoch 168/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2895 - accuracy: 0.9023
# Epoch 169/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2372 - accuracy: 0.9248
# Epoch 170/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2207 - accuracy: 0.9173
# Epoch 171/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3100 - accuracy: 0.9023
# Epoch 172/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1839 - accuracy: 0.9398
# Epoch 173/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2483 - accuracy: 0.9398
# Epoch 174/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1872 - accuracy: 0.9398
# Epoch 175/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2634 - accuracy: 0.9098
# Epoch 176/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1752 - accuracy: 0.9248
# Epoch 177/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2212 - accuracy: 0.9323
# Epoch 178/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1667 - accuracy: 0.9323
# Epoch 179/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1737 - accuracy: 0.9323
# Epoch 180/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2336 - accuracy: 0.9173
# Epoch 181/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2254 - accuracy: 0.9248
# Epoch 182/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1888 - accuracy: 0.9398
# Epoch 183/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1521 - accuracy: 0.9323
# Epoch 184/200
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2228 - accuracy: 0.9248
# Epoch 185/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1947 - accuracy: 0.9023
# Epoch 186/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1791 - accuracy: 0.9474
# Epoch 187/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2460 - accuracy: 0.9173
# Epoch 188/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2260 - accuracy: 0.9173
# Epoch 189/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2142 - accuracy: 0.9173
# Epoch 190/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2755 - accuracy: 0.8797
# Epoch 191/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2625 - accuracy: 0.9323
# Epoch 192/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3265 - accuracy: 0.8947
# Epoch 193/200
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2014 - accuracy: 0.9173
# Epoch 194/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1860 - accuracy: 0.9474
# Epoch 195/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2610 - accuracy: 0.8797
# Epoch 196/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1912 - accuracy: 0.9474
# Epoch 197/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2094 - accuracy: 0.9098
# Epoch 198/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1882 - accuracy: 0.9323
# Epoch 199/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2163 - accuracy: 0.9173
# Epoch 200/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2038 - accuracy: 0.9173
# Done

# %%
# for intent in intents['intents']:
#     print(intent['patterns'])
# l = len(intents['intents'])
# for i in range(0,l):
#     for j in intents['intents'][i]:
#         print(j)
# #     print(intents['intents'][i]['patterns'])

# %%
import random
import json
import pickle
import numpy as np
import nltk
from nltk.stem import WordNetLemmatizer
from tensorflow.keras.models import load_model
lemmatizer=WordNetLemmatizer()
intents=json.loads(open('medint.json').read())
words=pickle.load(open('words.pkl','rb'))
classes=pickle.load(open('classes.pkl','rb'))
model=load_model('chatbotmodel.h5')

def clean_up_sentence(sentence):
  sentence_words = nltk.word_tokenize(sentence)
  sentence_words = [lemmatizer.lemmatize(word) for word in sentence_words]
  return sentence_words

def bag_of_words(sentence):
  sentence_words = clean_up_sentence(sentence)
  bag = [0] * len(words)
  for w in sentence_words:
    for i, word in enumerate(words):
      if word == w:
        bag[i] = 1
  return np.array(bag)

def predict_class(sentence):
  bow = bag_of_words(sentence)
  res = model.predict(np.array([bow]))[0]
  ERROR_THRESHOLD = 0.25
  results = [[i,r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]

  results.sort(key=lambda x:x[1], reverse=True)
  return_list = []
  for r in results:
    return_list.append({'intent':classes[r[0]],'probability':str(r[1])})
  return return_list
def get_response(intents_list, intents_json):
  tag = intents_list[0]['intent']
  list_of_intents = intents_json['intents']
  for i in list_of_intents:
    if i['tag'] == tag:
      result = random.choice(i['responses'])
      break
  return result
print("GO! Bot is running!")

while True:
    message = input("You:")
    ints = predict_class(message)
    res = get_response(ints, intents)
    print("Medibot:",res)
# Out:
# GO! Bot is running!
# You:hi
# 1/1 [==============================] - 0s 91ms/step
# Medibot: hey!
# You:who are you
# 1/1 [==============================] - 0s 23ms/step
# Medibot: i am Medbot your medical assistant
# You:who made you
# 1/1 [==============================] - 0s 23ms/step
# Medibot: i am Medbot your medical assistant
# You:how r u
# 1/1 [==============================] - 0s 24ms/step
# Medibot: hey!
# You:cya
# 1/1 [==============================] - 0s 23ms/step
# Medibot: goodbye
# You:help
# 1/1 [==============================] - 0s 23ms/step
# Medibot: It seems that you are suffering from fever
# You:yup
# 1/1 [==============================] - 0s 24ms/step
# Medibot: It seems that you are suffering from fever

# %%
# for i in intents['intents']:
#     print(i)

# %%
# %%writefile medint.json
# {"intents":[
#             {
#              "tag":"greetings",
#              "patterns": ["hello","hey","hi","good day","greetings","what's up?","how is it going"],
#              "responses":["hello","hey!","what can i do for you?"]
#             },
#             {
#              "tag":"goodbye",
#              "patterns": ["cya","see you later","goodbye","have a good day","bye","cao","see ya"],
#              "responses":["have a nice day","goodbye"]
#             },
#             {
#              "tag":"age",
#              "patterns": ["how old","how old are you?","what is your age","how old are you","age?"],
#              "responses":["I get reborn after every compilation","hey!","my owners are averagely 20 years!"]
#             },
#             {
#              "tag":"name",
#              "patterns": ["what is your name","what should i call you","what's your name?","who are you?","can you tell me your name"],
#              "responses":["you can call me Medbot!","i am Medbot!","i am Medbot your medical assistant"]
#             },
#             {
#              "tag":"common cold symptoms",
#              "patterns": ["Runny or stuffy nose","Sore throat","Cough","Congestion","Slight body aches or a mild headache","Sneezing","Low-grade fever","Generally feeling unwell (malaise)"],
#              "responses":["It seems that you are suffering from common cold"]
#             },
#             {
#              "tag":"fever symptoms",
#              "patterns":["Sweating","Chills and shivering","Headache","Muscle aches","Loss of appetite","Irritability","Dehydration","General weakness"],
#              "responses":["It seems that you are suffering from fever"]
#             },
#             {
#              "tag":"Diabetes symptoms",
#              "patterns":["increased hunger","increased thirst","weight loss","frequent urination","blurry vision","extreme fatigue"],
#              "responses":["It seems that you are suffering from Diabetes"]
#             },
#             {
#              "tag":"Typhoid",
#              "patterns":["Continues fever, headache , slow pulse rate","reddish rashes appear on the belly","ulcers rupture"],
#              "responses":["It seems that you are suffering from Typhoid"]
#             },
#             {
#              "tag":"Depression symptoms",
#              "patterns":["Hopeless outlook","Lost interest","Increased fatigue","sleep problem","Anxiety","change in weight","Looking at death"],
#              "responses":["It seem that you are suffering from depression"]
#             },
#             {
#              "tag": "Bronchitis",
#              "patterns":["Cough is severe or lasts longer than three weeks", "Constant fever (temperature 38 degree celsius or above) for more than three days","Cough up mucus streaked with blood","having underlying heart or lung condition such as asthma or heart failure"],
#              "responses":["It seems that you are suffering from depression"]
#             },
#             {
#              "tag":"Allergy",
#              "patterns":["Irritation","runny nose","stuffy nose","puffy","watery eyes","sneezing","Inflammed,itchy nose and throught","Skin rashes","Diarrhea","nausea","vomiting excessing gas in digestion","swelling of lips,face,tongue","itchiness","difficulty in breathing"],
#              "responses":["it seems that you are suffering from Allergy"]
#             },
#             {
#              "tag":"Chest infection",
#              "patterns":["Persistant cough","Cough of yellow or green phlegm(thick mucus) or coughing up blood","breathlessness or rapid and shallow breathing","wheezing","high temperature fever","rapid heartbeat","chest pain or tightness","feeling confused and disorientated"],
#              "responses":["it seems that you are suffering from chest infection"]
#             },
#             {
#              "tag":"Asthma symptoms",
#              "patterns":["coughing","tightness in the chest","shortness of breath","difficulty talking","panic","fatigue"],
#              "responses":["It seem that you are suffering from Asthma"]
#             },
#             {
#              "tag":"Chicken pox",
#              "patterns":["Fever , headache and lose of apetite","Dark red - coloured rash on the back and chest which spreads on the whole body later change into vessicles","crusts are formed"],
#              "responses":["It seem that you are suffering from Chicken pox"]
#             },
#             {
#              "tag":"eczema",
#              "patterns":["Dry cracked skin ","itchiness (pruritus)","rash on swollen skin that varies in color depending on your skin color","small , raced bumps on brown or black skin ", "oozing and crusting","thickened skin","darkening of skin around the eyes","Raw sensitive skin from scratching"],
#              "responses":["It seem that you are suffering from eczema"]
#             },
#             {
#              "tag":"common cold prevention",
#              "patterns":["What medicines can I buy to help me with my common cold?","tell me some prevention method from common cold","What should I eat or drink if i am suffering from common cold?","How can I keep from getting a cold or the flu?"],
#              "responses":["medicines you can consume : Dextromethorphan,Decongestant,Diphenhydramine,Crocin Cold & Flu Max, preventions that you must follow :Wash your hands,Avoid touching your face,Clean frequently used surfaces,Use hand sanitizers,SUGGESTED FOODS ARE:Garlic,Vitamin C–containing fruits,Leafy greens,Broccoli,Oatmeal,Spices,Chicken Soup"]
#             },
#             {
#              "tag":"fever prevention",
#              "patterns":["What medicines can I buy to help me with my fever?","tell me some prevention method from fever","What should I eat or drink if i am suffering from fever?","How can I keep from getting a fever?"],
#              "responses":["medicines you can consume : acetaminophen ,ibuprofen,aspirin,Crocin Cold & Flu Max, prevention that you must follow :Wash your hands,Cover your mouth when you cough and your nose when you sneeze,Clean frequently used surfaces,Avoid sharing cups, glasses, and eating utensils with other people.,SUGGESTED FOODS ARE:Garlic,Vitamin C–containing fruits,Leafy greens,Broccoli,Oatmeal,Spices,Chicken Soup"]
#             },
#             {
#              "tag":"Typhoid  prevention",
#              "patterns":["tell me some prevention method from typhoid","How can I cure from typhoid","How can I keep from getting a typhoid"],
#              "responses":["Anti-typhoid inoculation should be given","avoid taking exposed food and drinks","proper sanitation and cleanlinessness should be maintained","Proper disposal of excreta of the patient","anti-biotics should be administrated"]
#             },
#             {
#              "tag":"diabetes prevention",
#              "patterns":["What medicines can I buy to help me with my diabetes?","tell me some prevention method from diabetes","What should I eat or drink if i am suffering from diabetes?","How can I keep from getting diabetes?"],
#              "responses":["medicines you can consume : Insulin ,Amylinomimetic drug,Dipeptidyl peptidase-4 (DPP-4) inhibitor, prevention that you must follow :Cut Sugar and Refined Carbs From Your Diet,Work Out Regularly,Drink Water as Your Primary Beverage,Lose Weight If You’re Overweight or Obese,Quit Smoking, Follow a Very-Low-Carb Diet,Watch Portion Sizes,SUGGESTED FOODS ARE:Leafy greens,Avocados,Eggs"]
#             },
#             {
#              "tag":"depression prevention",
#              "patterns":["What medicines can I buy to help me with my depression?","tell me some prevention method from depression","What should I eat or drink if i am suffering from depression?","How can I keep from getting depression?"],
#              "responses":["medicines you can consume :  brexpiprazole, quetiapine,olanzapine, prevention that you must follow :Exercise regularly,Cut back on social media time,Drink Water as Your Primary Beverage,Build strong relationships,Minimize your daily choices, Follow a Very-Low-Carb Diet,SUGGESTED FOODS ARE:Get Enough Vitamin D,Include Omega-3 Fatty Acids,Beans and legumes"]
#             },
#             {
#              "tag":"asthma prevention",
#              "patterns":["What medicines can I buy to help me with my asthma?","tell me some prevention method from asthma","What should I eat or drink if i am suffering from asthma?","How can I keep from getting asthma?"],
#              "responses":["medicines you can consume : epinephrine,anticholinergic,Proair HFA, prevention that you must follow : Identify Asthma Triggers, Stay Away From Allergens,Avoid Smoke of Any Type,SUGGESTED FOODS ARE:carrots,juice,eggs,broccoli,cantaloupe,milk"]
#             },
#             {
#              "tag":"Chest infection prevention",
#              "patterns":["Tell me some prevention method from chest infection","What are the things which keep on my mind when I have chest infection","How can I recover my chest infection"],
#              "responses":["get plenty of rest,drink lot of fluid to prevent dehydration and to loosen mucus in your lungus, making it easier to cough up","treat headaches, fever and aches, and pains with pain releaves","drink a warm drink of honey and lemon to releave soar throat caused by persistent coughing","raise your head up with extra pillows while you are sleeping to make breathing easier","stop smoking if you smoke"]
#             },
#             {
#              "tag":"Chicken pox prevention",
#              "patterns":["Tell me some prevention for chicken pox","What are the things which keep on my mind when I have chicken pox","How can cure  chicken pox"],
#              "responses":["You should be kept in isolation","clothings, utensils, e.t.c used by the patient should be sterilized","falling crusts should be collected and burnt"]
#             },
#             {
#              "tag":"Consultation",
#              "patterns": ["who should i contact for consultation?","is there any doctor available?","can you give me some suggestions for doctor consultations?","can you set up a meeting with a doctor for consultation?","is there any doctor available for consultation"],
#              "responses":["You can contact various doctors here for any kind of consultation: 1. https://www.1mg.com/online-doctor-consultation, 2. https://www.tatahealth.com/online-doctor-consultation/general-physician, 3. https://www.doconline.com/, or you can pay a visit to your local area doctor or family doctor."]
#             }
#            ]
# }
# Out:
# Overwriting medint.json

# %%
import random
import json
import pickle
import numpy as np
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
lemmatizer=WordNetLemmatizer()
intents=json.loads(open('medint.json').read())

words=[]
classes=[]
documents=[]
ignore_letters = ['?','!','.',',']
for intent in intents['intents']:
  for pattern in intent['patterns']:
    word_list = nltk.word_tokenize(pattern)
    words.extend(word_list)
    documents.append((word_list,intent['tag']))
    if intent['tag'] not in classes:
      classes.append(intent['tag'])

# print(documents)
words = [lemmatizer.lemmatize(word) for word in words if words not in ignore_letters]
words = sorted(set(words))
classes = sorted(set(classes))
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
training=[]
output_empty = [0]*len(classes)
for document in documents:
  bag=[]
  word_patterns=document[0]
  word_patterns=[lemmatizer.lemmatize(word.lower()) for word in word_patterns]
  for word in words:
    bag.append(1) if word in word_patterns else bag.append(0)
  output_row = list(output_empty)
  output_row[classes.index(document[1])] = 1
  training.append([bag,output_row])
random.shuffle(training)
training = np.array(training)
train_x = list(training[:, 0])
train_y = list(training[:, 1])
model = Sequential()
model.add(Dense(128,input_shape=(len(train_x[0]),),activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]),activation='softmax'))
sgd=tf.keras.optimizers.legacy.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbotmodel.h5')
print('Done')
# print(words)

# import random
# import json
# import pickle
# import numpy as np
# import nltk
from nltk.stem import WordNetLemmatizer
from tensorflow.keras.models import load_model
lemmatizer=WordNetLemmatizer()
intents=json.loads(open('medint.json').read())
words=pickle.load(open('words.pkl','rb'))
classes=pickle.load(open('classes.pkl','rb'))
model=load_model('chatbotmodel.h5')

def clean_up_sentence(sentence):
  sentence_words = nltk.word_tokenize(sentence)
  sentence_words = [lemmatizer.lemmatize(word) for word in sentence_words]
  return sentence_words

def bag_of_words(sentence):
  sentence_words = clean_up_sentence(sentence)
  bag = [0] * len(words)
  for w in sentence_words:
    for i, word in enumerate(words):
      if word == w:
        bag[i] = 1
  return np.array(bag)

def predict_class(sentence):
  bow = bag_of_words(sentence)
  res = model.predict(np.array([bow]))[0]
  ERROR_THRESHOLD = 0.25
  results = [[i,r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]

  results.sort(key=lambda x:x[1], reverse=True)
  return_list = []
  for r in results:
    return_list.append({'intent':classes[r[0]],'probability':str(r[1])})
  return return_list
def get_response(intents_list, intents_json):
  tag = intents_list[0]['intent']
  list_of_intents = intents_json['intents']
  for i in list_of_intents:
    if i['tag'] == tag:
      result = random.choice(i['responses'])
      break
  return result
print("GO! Bot is running!")

while True:
    message = input("You:")
    ints = predict_class(message)
    res = get_response(ints, intents)
    print("Medibot:",res)
# Out:
# Epoch 1/200
# [nltk_data] Downloading package punkt to /home/sushanth/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/sushanth/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/sushanth/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# /tmp/ipykernel_120674/2402797473.py:47: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)
# 27/27 [==============================] - 1s 2ms/step - loss: 3.2039 - accuracy: 0.0451
# Epoch 2/200
# 27/27 [==============================] - 0s 3ms/step - loss: 3.1498 - accuracy: 0.0602
# Epoch 3/200
# 27/27 [==============================] - 0s 3ms/step - loss: 3.0678 - accuracy: 0.1278
# Epoch 4/200
# 27/27 [==============================] - 0s 2ms/step - loss: 3.0637 - accuracy: 0.1278
# Epoch 5/200
# 27/27 [==============================] - 0s 3ms/step - loss: 2.9354 - accuracy: 0.1654
# Epoch 6/200
# 27/27 [==============================] - 0s 3ms/step - loss: 2.8247 - accuracy: 0.1654
# Epoch 7/200
# 27/27 [==============================] - 0s 4ms/step - loss: 2.7899 - accuracy: 0.1579
# Epoch 8/200
# 27/27 [==============================] - 0s 3ms/step - loss: 2
200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3539 - accuracy: 0.9173
# Epoch 72/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3051 - accuracy: 0.8947
# Epoch 73/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4539 - accuracy: 0.8722
# Epoch 74/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3531 - accuracy: 0.8647
# Epoch 75/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3967 - accuracy: 0.8722
# Epoch 76/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3211 - accuracy: 0.9098
# Epoch 77/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3382 - accuracy: 0.9023
# Epoch 78/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3145 - accuracy: 0.8872
# Epoch 79/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3021 - accuracy: 0.9023
# Epoch 80/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2774 - accuracy: 0.9398
# Epoch 81/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3401 - accuracy: 0.8947
# Epoch 82/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3418 - accuracy: 0.8722
# Epoch 83/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3590 - accuracy: 0.8722
# Epoch 84/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2673 - accuracy: 0.9098
# Epoch 85/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3014 - accuracy: 0.8797
# Epoch 86/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4037 - accuracy: 0.8722
# Epoch 87/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3994 - accuracy: 0.8496
# Epoch 88/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2748 - accuracy: 0.9248
# Epoch 89/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2636 - accuracy: 0.9173
# Epoch 90/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3140 - accuracy: 0.8872
# Epoch 91/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2029 - accuracy: 0.9248
# Epoch 92/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2472 - accuracy: 0.9248
# Epoch 93/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2924 - accuracy: 0.9173
# Epoch 94/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2811 - accuracy: 0.8872
# Epoch 95/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2959 - accuracy: 0.8797
# Epoch 96/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3488 - accuracy: 0.8797
# Epoch 97/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2636 - accuracy: 0.9173
# Epoch 98/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3665 - accuracy: 0.8647
# Epoch 99/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3223 - accuracy: 0.8647
# Epoch 100/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2665 - accuracy: 0.9023
# Epoch 101/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3404 - accuracy: 0.9023
# Epoch 102/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3429 - accuracy: 0.8571
# Epoch 103/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2003 - accuracy: 0.9398
# Epoch 104/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2666 - accuracy: 0.9248
# Epoch 105/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2667 - accuracy: 0.9098
# Epoch 106/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2908 - accuracy: 0.8872
# Epoch 107/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3177 - accuracy: 0.8496
# Epoch 108/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3863 - accuracy: 0.8722
# Epoch 109/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2967 - accuracy: 0.8872
# Epoch 110/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3303 - accuracy: 0.9023
# Epoch 111/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2864 - accuracy: 0.8872
# Epoch 112/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2839 - accuracy: 0.8947
# Epoch 113/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3001 - accuracy: 0.8947
# Epoch 114/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3672 - accuracy: 0.8647
# Epoch 115/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3057 - accuracy: 0.8722
# Epoch 116/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2433 - accuracy: 0.9323
# Epoch 117/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2797 - accuracy: 0.8872
# Epoch 118/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3134 - accuracy: 0.8947
# Epoch 119/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2277 - accuracy: 0.9023
# Epoch 120/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2267 - accuracy: 0.8947
# Epoch 121/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2159 - accuracy: 0.9323
# Epoch 122/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2933 - accuracy: 0.8947
# Epoch 123/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2194 - accuracy: 0.9248
# Epoch 124/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2440 - accuracy: 0.9173
# Epoch 125/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2777 - accuracy: 0.9173
# Epoch 126/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2345 - accuracy: 0.9023
# Epoch 127/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2357 - accuracy: 0.9098
# Epoch 128/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2134 - accuracy: 0.9323
# Epoch 129/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2345 - accuracy: 0.9098
# Epoch 130/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2690 - accuracy: 0.8947
# Epoch 131/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2104 - accuracy: 0.9398
# Epoch 132/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2603 - accuracy: 0.9173
# Epoch 133/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1653 - accuracy: 0.9474
# Epoch 134/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2235 - accuracy: 0.9248
# Epoch 135/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1656 - accuracy: 0.9474
# Epoch 136/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1949 - accuracy: 0.9398
# Epoch 137/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2124 - accuracy: 0.9474
# Epoch 138/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2136 - accuracy: 0.9173
# Epoch 139/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1973 - accuracy: 0.9474
# Epoch 140/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2312 - accuracy: 0.9173
# Epoch 141/200
# 27/27 [==============================] - 0s 4ms/step - loss: 0.3333 - accuracy: 0.8647
# Epoch 142/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2974 - accuracy: 0.8947
# Epoch 143/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2527 - accuracy: 0.9098
# Epoch 144/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2151 - accuracy: 0.9323
# Epoch 145/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2479 - accuracy: 0.8947
# Epoch 146/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2270 - accuracy: 0.9098
# Epoch 147/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1887 - accuracy: 0.9323
# Epoch 148/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1921 - accuracy: 0.9323
# Epoch 149/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2017 - accuracy: 0.9474
# Epoch 150/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2424 - accuracy: 0.9323
# Epoch 151/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2197 - accuracy: 0.9173
# Epoch 152/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2247 - accuracy: 0.9248
# Epoch 153/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2431 - accuracy: 0.8947
# Epoch 154/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2168 - accuracy: 0.9248
# Epoch 155/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2082 - accuracy: 0.9248
# Epoch 156/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1851 - accuracy: 0.9398
# Epoch 157/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2145 - accuracy: 0.9248
# Epoch 158/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2685 - accuracy: 0.9173
# Epoch 159/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1630 - accuracy: 0.9474
# Epoch 160/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2255 - accuracy: 0.9173
# Epoch 161/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1655 - accuracy: 0.9248
# Epoch 162/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2553 - accuracy: 0.9023
# Epoch 163/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2295 - accuracy: 0.9098
# Epoch 164/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2410 - accuracy: 0.8872
# Epoch 165/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2022 - accuracy: 0.9323
# Epoch 166/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2401 - accuracy: 0.9173
# Epoch 167/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2644 - accuracy: 0.9248
# Epoch 168/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2007 - accuracy: 0.9323
# Epoch 169/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1363 - accuracy: 0.9474
# Epoch 170/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1947 - accuracy: 0.9624
# Epoch 171/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2518 - accuracy: 0.9248
# Epoch 172/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2587 - accuracy: 0.9098
# Epoch 173/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1440 - accuracy: 0.9549
# Epoch 174/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1626 - accuracy: 0.9474
# Epoch 175/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2271 - accuracy: 0.9323
# Epoch 176/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2292 - accuracy: 0.9248
# Epoch 177/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2591 - accuracy: 0.9098
# Epoch 178/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1930 - accuracy: 0.9398
# Epoch 179/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2221 - accuracy: 0.9248
# Epoch 180/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1307 - accuracy: 0.9624
# Epoch 181/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1918 - accuracy: 0.9323
# Epoch 182/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2131 - accuracy: 0.9323
# Epoch 183/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2892 - accuracy: 0.8722
# Epoch 184/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2155 - accuracy: 0.9098
# Epoch 185/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1725 - accuracy: 0.9398
# Epoch 186/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1542 - accuracy: 0.9474
# Epoch 187/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1705 - accuracy: 0.9248
# Epoch 188/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1492 - accuracy: 0.9474
# Epoch 189/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1746 - accuracy: 0.9624
# Epoch 190/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1408 - accuracy: 0.9624
# Epoch 191/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2160 - accuracy: 0.9323
# Epoch 192/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1435 - accuracy: 0.9398
# Epoch 193/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2373 - accuracy: 0.9173
# Epoch 194/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1582 - accuracy: 0.9474
# Epoch 195/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2545 - accuracy: 0.9098
# Epoch 196/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1953 - accuracy: 0.9248
# Epoch 197/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1528 - accuracy: 0.9398
# Epoch 198/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2235 - accuracy: 0.9098
# Epoch 199/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1839 - accuracy: 0.9323
# Epoch 200/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2288 - accuracy: 0.9248
# Done
# GO! Bot is running!
# You:hi
# 1/1 [==============================] - 0s 93ms/step
# Medibot: hey!
# You:i have fever
# 1/1 [==============================] - 0s 23ms/step
# Medibot: medicines you can consume : acetaminophen ,ibuprofen,aspirin,Crocin Cold & Flu Max, prevention that you must follow :Wash your hands,Cover your mouth when you cough and your nose when you sneeze,Clean frequently used surfaces,Avoid sharing cups, glasses, and eating utensils with other people.,SUGGESTED FOODS ARE:Garlic,Vitamin C–containing fruits,Leafy greens,Broccoli,Oatmeal,Spices,Chicken Soup
# You:what ae the symptoms of fever?
# 1/1 [==============================] - 0s 23ms/step
# Medibot: It seem that you are suffering from Chicken pox
